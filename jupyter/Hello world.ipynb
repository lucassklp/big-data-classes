# %%
import pyspark 
from pyspark.sql import SQLContext, SparkSession

# %%
sc = SparkSession \
        .builder \
        .master('spark://spark:7077') \
        .appName("sparkFromJupyter") \
        .getOrCreate()
# Out:
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/02/17 23:33:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 22/02/17 23:33:10 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
